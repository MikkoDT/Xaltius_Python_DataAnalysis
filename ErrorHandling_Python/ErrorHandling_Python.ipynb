# %%
# Syntax error
value = 4
sentence = 'this is python session
print(value)
# Out:
#   File "<ipython-input-1-cb592d348a27>", line 3
#     sentence = 'this is python session
#                                       ^
# SyntaxError: EOL while scanning string literal

# %%
# Indentation error
for i in range(3):
j = i*2
  print(i,j)
# Out:
#   File "<ipython-input-2-fe603332536f>", line 3
#     j = i*2
#     ^
# IndentationError: expected an indented block

# %%
# Type Error
subtract_eg = "python"-"prog"
print(subtract_eg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-55ae8d9e5eee> in <cell line: 2>()
#       1 # Type Error
# ----> 2 subtract_eg = "python"-"prog"
#       3 print(subtract_eg)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
#Index Error
string_ex = 'ahngdkess'
print(string_ex[15])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-3a5ab9e6e753> in <cell line: 3>()
#       1 #Index Error
#       2 string_ex = 'ahngdkess'
# ----> 3 print(string_ex[15])
#
# IndexError: string index out of range

# %%
# Attributte error
print(len(string_ex))
print(string_ex.len)
# Out:
# 9
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-3b375dccdedf> in <cell line: 3>()
#       1 # Attributte error
#       2 print(len(string_ex))
# ----> 3 print(string_ex.len)
#
# AttributeError: 'str' object has no attribute 'len'
